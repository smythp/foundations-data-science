# %% [markdown]
# # Data Analysis Exercise

# %%
import pandas

# %%
df = pandas.read_csv('http://bit.ly/airbnbcsv')

# %%
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
# Pull out a column

df.name
# Out:
# 0                       Clean & quiet apt home by the park
# 1                                    Skylit Midtown Castle
# 2                      THE VILLAGE OF HARLEM....NEW YORK !
# 3                          Cozy Entire Floor of Brownstone
# 4         Entire Apt: Spacious Studio/Loft by central park
#                                ...
# 48890      Charming one bedroom - newly renovated rowhouse
# 48891        Affordable room in Bushwick/East Williamsburg
# 48892              Sunny Studio at Historical Neighborhood
# 48893                 43rd St. Time Square-cozy single bed
# 48894    Trendy duplex in the very heart of Hell's Kitchen
# Name: name, Length: 48895, dtype: object

# %%
df.price > 20
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 48890    True
# 48891    True
# 48892    True
# 48893    True
# 48894    True
# Name: price, Length: 48895, dtype: bool

# %%
expensive_booleans = df.price > 400

# %%
df[expensive_booleans]
# Out:
#              id                                               name    host_id  \
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 158       38663                   Luxury Brownstone in Boerum Hill     165789
# 233       60164                 Beautiful, elegant 3 bed SOHO loft     289653
# 242       61224                                  Huge Chelsea Loft     291112
# ...         ...                                                ...        ...
# 48740  36413632         Spacious 2BR in Beautiful Brooklyn Heights    6608220
# 48744  36415840         A BEAUTIFUL SPACE IN HEART OF WILLIAMSBURG  223715460
# 48757  36419574     Luxury & Spacious 1500 ft² MANHATTAN Townhouse   11454384
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
#
# ...

# %%
groceries = ['milk', 'eggs', 'cheese']

groceries[-1]
# Out:
# 'cheese'

# %%
"CUNY"[-1]
# Out:
# 'Y'

# %%
"City College is super cool"[5:10]
# Out:
# 'Colle'

# %%
df.iloc[0]
# Out:
# id                                                              2539
# name                              Clean & quiet apt home by the park
# host_id                                                         2787
# host_name                                                       John
# neighbourhood_group                                         Brooklyn
# neighbourhood                                             Kensington
# latitude                                                    40.64749
# longitude                                                  -73.97237
# room_type                                               Private room
# price                                                            149
# minimum_nights                                                     1
# number_of_reviews                                                  9
# last_review                                               2018-10-19
# reviews_per_month                                               0.21
# ...

# %%
df.price[0:1000]
# Out:
# 0      149
# 1      225
# 2      150
# 3       89
# 4       80
#       ...
# 995    125
# 996    125
# 997    145
# 998    147
# 999    123
# Name: price, Length: 1000, dtype: int64

# %%
jackson_bools = df.neighbourhood == 'Jackson Heights'

jackson_bools
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Name: neighbourhood, Length: 48895, dtype: bool

# %%
len(df)
# Out:
# 48895

# %%
jackson_df = df[jackson_bools]

# %%
jackson_df.price.mean()
# Out:
# 80.89784946236558

# %%
df.price.mean() - jackson_df.price.mean()
# Out:
# 71.82283772446333

# %%
jackson_df.price.median() - df.price.median()
# Out:
# -37.5

# %% [markdown]
# Steps to get the average rental price in Jackson Heights:
#
# - Pull out neighbourhood column
# - Compare to find the booleans that correspond to Jackson Height
# - Save the boolean series to a variable
# - Use boolean list to index
# - SaveJackson Heights data frame to variable
# - Pull out the price column
# - Find the mean of the price column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
longer_stay = df.minimum_nights > 7

# %%
df[longer_stay]
# Out:
#              id                                               name    host_id  \
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 14         6090                      West Village Nest - Superhost      11975
# 27         9357                               Midtown Pied-a-terre      30193
# 29         9657                   Modern 1 BR / NYC / EAST VILLAGE      21904
# ...         ...                                                ...        ...
# 48843  36453642     ☆  HUGE, SUNLIT Room - 3 min walk from Train !   53966115
# 48871  36475746      A LARGE ROOM - 1 MONTH MINIMUM - WASHER&DRYER  144008701
# 48879  36480292  Gorgeous 1.5 Bdr with a private yard- Williams...     540335
# 48882  36482231                          Bushwick _ Myrtle-Wyckoff   66058896
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
#
# ...

# %%
bools = df.minimum_nights > 7

# %%
longer_stay_df = df[bools]

# %%
len(longer_stay_df)
# Out:
# 7333

# %%
len(bools)
# Out:
# 48895
